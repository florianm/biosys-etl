# %% [markdown]
# ## CKAN helper functions

# %%
import requests, json, urllib
from secret import CKAN

url = CKAN["dpaw-internal"]["url"]
key = CKAN["dpaw-internal"]["key"]

# Dictionaries from CKAN ---------------------------------------------------------------------#
def get_all_dataset_dicts(url, limit=None, offset=None):
    """Returns a list of package dicts including resources

    @see http://docs.ckan.org/en/latest/api/index.html#ckan.logic.action.get.current_package_list_with_resources
    :param url: A live CKAN URL
    :param limit: The max number of dataset dicts returned, optional
    :param offset: The offset, optional
    """
    url = "{0}api/3/action/current_package_list_with_resources".format(url)
    parameters = {}
    if limit:
        parameters["limit"] = limit
    if offset:
        parameters["offset"] = offset
    datadict = urllib.quote(json.dumps(parameters))
    
    r = requests.get(url, data=datadict)
    return json.loads(r.content)["result"]


def get_dataset_dicts_for_group(group_name, url):
    """Returns a list of package dicts including resources for a group

    :param group_name: the group name as string
    :param rl: A live CKAN URL
    """
    r = requests.get("{0}api/3/action/group_show?id={1}".format(api_url, group_name))
    return json.loads(r.content)["result"]["packages"]

def get_dataset_dicts_for_tag(tag_name, url):
    """Returns a list of package dicts including resources for a tag

    :param tag_name: the tag name as string
    :param url: A live CKAN URL
    """
    r = requests.get("{0}api/3/action/tag_show?id={1}".format(url, tag_name))
    return json.loads(r.content)["result"]["packages"]


def get_tag_dict_from_tag_name(tag_name, url):
    """Returns a dict of the CKAN tag without the package dict.

    :param tag_name: the tag name as string
    :param url: A live CKAN URL
    """
    r = requests.get("{0}api/3/action/tag_show?id={1}".format(url, tag_name))
    tag_dict = json.loads(r.content)["result"]
    tag_dict.pop("packages", None)
    return tag_dict


# Manipulate one dataset dict ----------------------------------------------------------------#
def add_last_updated_fields(dataset_dict, url, api_key):
    """Updates a dataset dictionary and posts back to CKAN

    Here: add "extra" fields 
    "Last updated on" (set to date of last edit) and 
    "Last updated by" (set to author)
    only if "Last updated by" does not exist

    :param dataset_dict: The dataset as dict from CKAN
    :param url: A live CKAN URL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """
    update_url = "{0}api/3/action/package_update".format(url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    lub = "Last updated by"
    luo = "Last updated on"
    
    if lub not in [x["key"] for x in dt["extras"]]:
        dt["extras"] += [
            {u"key":lub, u"value":dt["author"]},
            {u"key":luo,u"value":dt["metadata_modified"]}
        ]
        datadict = urllib.quote(json.dumps(dt))
        
        r = requests.post(update_url, data=datadict, headers=headers)
        print("Updated: {0}".format(dataset_name))
        return True
    else:
        print("Unchanged: {0}".format(dataset_name))
        return False

    
def rename_extra_field(dataset_dict, old_name, new_name, url, api_key):
    """Update the name of one extra field from old_name to new_name.
    
    Usage:
    [rename_extra_field(d, "old name", "new name") for d in package_names]

    :param dataset_dict: The dataset as dict from CKAN
    :param old_name: the extra field you wish to change
    :param new_name: the new name for the changed extra field
    :param url: A live CKAN URL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """
    update_url = "{0}api/3/action/package_update".format(url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    
    if old_name in [x["key"] for x in dataset_dict["extras"]]:
        for x in dataset_dict["extras"]:
            if x["key"] == old_name:
                x["key"] = new_name
        datadict = urllib.quote(json.dumps(dataset_dict))
        r = requests.post(update_url, data=datadict, headers=headers)
        print("Updated: {0}".format(dataset_dict["name"]))
        return True
    else:
        print("Unchanged: {0}".format(dataset_dict["name"]))
        return False

def migrate_extra_field(dataset_dict, old_name, new_name, url, api_key):
    """Copy the content of extra field with key "old_name" to dataset_dict 
    field with key "new_name".
    
    Usage:
    [rename_extra_field(d, "old name", "new name") for d in package_names]

    :param dataset_dict: The dataset as dict from CKAN
    :param old_name: the extra field you wish to change
    :param new_name: the new name for the changed extra field
    :param url: A live CKAN URL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """
    update_url = "{0}api/3/action/package_update".format(url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    
    if old_name in [x["key"] for x in dataset_dict["extras"]]:
        for x in dataset_dict["extras"]:
            if x["key"] == old_name:
                dataset_dict[new_name] = x["value"]
        datadict = urllib.quote(json.dumps(dataset_dict))
        r = requests.post(update_url, data=datadict, headers=headers)
        print("Updated: {0}".format(dataset_dict["name"]))
        return True
    else:
        print("Unchanged: {0}".format(dataset_dict["name"]))
        return False
        
    
def add_tag_to_dataset(dataset_dict, tag_dict, url, api_key):
    """Adds a tag to a dataset.

    :param dataset_dict: The dataset as dict from CKAN
    :param tag_dict: The tag as dict from CKAN
    :param api_url: A live CKAN RL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """
    update_url = "{0}api/3/action/package_update".format(url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    
    if tag_dict["name"] not in [t["name"] for t in dataset_dict["tags"]]:
        dataset_dict["tags"].append(tag_dict)
        datadict = urllib.quote(json.dumps(dataset_dict))
        r = requests.post(update_url, data=datadict, headers=headers)
        print("Tag not found, adding tag to {0}".format(dataset_dict["name"]))
        return True
    else:
        print("Tag found, skipping {0}".format(dataset_dict["name"]))
        return False
        
def update_resource_url(datadict, url, api_key):
    """Updates the URL of a resource.
    
    The old and new url parts are hard-coded. Modify to your needs.

    :param dataset_dict: The dataset as dict from CKAN
    :param url: A live CKAN URL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """    
    update_url = "{0}api/3/action/package_update".format(url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    
    #[r["url"] for r in d["resources"]]
    needs_update = False
    for resource in datadict["resources"]:
        if resource["url"].startswith("http://marine-data"):
            needs_update = True
            print("Old url: {0}".format(resource["url"]))
            resource["url"] = resource["url"].replace(
                "marine-data", "internal-data")
            print("changed to: {0}".format(resource["url"]))
        if resource["url"].startswith("http://ckan-private"):
            needs_update = True
            print("Old url: {0}".format(resource["url"]))
            resource["url"] = resource["url"].replace(
                "ckan-private", "internal-data")
            print("changed to: {0}".format(resource["url"]))
    if needs_update:
        dd = urllib.quote(json.dumps(datadict))
        r = requests.post(update_url, data=dd, headers=headers)
        print("Updated: {0}".format(datadict["name"]))
    else:
        print("Unchanged: {0}".format(datadict["name"]))
    return True

def migrate_extra_to_custom_fields(dataset_dict, api_url, api_key):
    """Copy the content of some extra fields to some custom field.

    :param dataset_dict: The dataset as dict from CKAN
    :param api_url: A live CKAN API URL
    :param api_key: A privileged CKAN API key
    :return: True if dataset was updated, False if not
    """
    update_url = "{0}package_update".format(api_url)
    headers = {'Authorization': api_key, 
                'content-type': 'application/x-www-form-urlencoded'}
    data_changed = False
    
    if 'extras' in dataset_dict.keys():
        print("Migrating {0}".format(dataset_dict["name"]))
        for e in dataset_dict['extras']:
            if e['key'] == 'spatial':
                dataset_dict['spatial'] = e['value']
                print('....spatial extent')
                data_changed = True
            elif e['key'] == 'Last updated on':
                dataset_dict['last_updated_on'] = e['value']
                print('....last updated on')
                data_changed = True
            elif e['key'] == 'Last updated by' and dataset_dict['maintainer'] == '':
                dataset_dict['maintainer'] = e['value']
                print('....last updated by -> maintainer')
                data_changed = True
            elif e['key'] == 'Data Source':
                dataset_dict['citation'] = e['value']
                print('....citation')
                data_changed = True
        del dataset_dict["extras"]
    
    if data_changed:
        datadict = urllib.quote(json.dumps(dataset_dict))
        r = requests.post(update_url, data=datadict, headers=headers)
        print("Updated: {0}".format(dataset_dict["name"]))
        return True
    else:
        print("Unchanged: {0}".format(dataset_dict["name"]))
        return False

# %%
# Export names and some info about all datasets to CSV
url1 = "{0}api/3/action/current_package_list_with_resources?limit=350".format(url)
url2 = "{0}api/3/action/current_package_list_with_resources?limit=350&offset=351".format(url)
url3 = "{0}}api/3/action/current_package_list_with_resources?limit=350&offset=700".format(url)
r1 = requests.get(url1)
r2 = requests.get(url2)
r3 = requests.get(url3)
ds = json.loads(r1.content)["result"] + json.loads(r2.content)["result"] + json.loads(r3.content)["result"]
len(ds)
# Out:
# 810

# %%
# Export names and some info about all datasets to CSV - TEST DATA
url1 = "http://test-data.dpaw.wa.gov.au/api/3/action/current_package_list_with_resources?limit=350"
url2 = "http://test-data.dpaw.wa.gov.au/api/3/action/current_package_list_with_resources?limit=350&offset=351"
url3 = "http://test-data.dpaw.wa.gov.au/api/3/action/current_package_list_with_resources?limit=350&offset=700"
r1 = requests.get(url1)
r2 = requests.get(url2)
r3 = requests.get(url3)
td = json.loads(r1.content)["result"] + json.loads(r2.content)["result"] + json.loads(r3.content)["result"]                
len(td)

# %%
api_url="{0}api/3/action/".format(url)

[migrate_extra_to_custom_fields(p, api_url, key) for p in ds]
# Out:
# Migrating warden-wetlands-systems-waterbirds-monitoring
# ....last updated on
# ....spatial extent
# Updated: warden-wetlands-systems-waterbirds-monitoring
# Migrating mpa-reports
# ....last updated on
# ....spatial extent
# Updated: mpa-reports
# Migrating number-of-vessels-utilising-the-barrow-island-port
# ....citation
# ....last updated on
# Updated: number-of-vessels-utilising-the-barrow-island-port
# Unchanged: gss-post-fire-fauna-trapping-and-microhabitat-surveys
# Migrating example-dataset
# ....spatial extent
# Updated: example-dataset
# Migrating coral-recruitment-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: coral-recruitment-at-ningaloo-mpa
# Unchanged: data-demo
# Migrating world-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: world-spatial-extent
# Migrating water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-orthophosphate
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-orthophosphate
# Migrating white-tip-reef-shark-among-coral-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: white-tip-reef-shark-among-coral-at-rowley-shoals-marine-park
# Migrating western-australia-spatial-extent-file
# ....last updated on
# ....spatial extent
# Updated: western-australia-spatial-extent-file
# Migrating water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-enterococci
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-enterococci
# Migrating water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-dissolved-inorganic-nitrogen
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-dissolved-inorganic-nitrogen
# Migrating water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-chlorophyll-a
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-on-the-shoreline-at-the-shoalwater-islands-mp-chlorophyll-a
# Migrating water-quality-in-geographe-bay
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# ....spatial extent
# Updated: water-quality-in-geographe-bay
# Migrating water-quality-at-the-shoalwater-islands-mp-total-phosphorus
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-total-phosphorus
# Migrating water-quality-at-the-shoalwater-islands-mp-total-nitrogen
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-total-nitrogen
# Migrating water-quality-at-the-shoalwater-islands-mp-orthophosphate
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-orthophosphate
# Migrating water-quality-at-the-shoalwater-islands-mp-nitrate-and-nitrite
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-nitrate-and-nitrite
# Migrating water-quality-at-the-shoalwater-islands-mp-light-attenuation
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-light-attenuation
# Migrating water-quality-at-the-shoalwater-islands-mp-dissolved-inorganic-nitrogen
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-dissolved-inorganic-nitrogen
# Migrating water-quality-at-the-shoalwater-islands-mp-chlorophyll-a
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-chlorophyll-a
# Migrating water-quality-at-the-shoalwater-islands-mp-ammonium
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp-ammonium
# Migrating water-quality-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: water-quality-at-the-shoalwater-islands-mp
# Migrating walpole-nornalup-inlets-marine-protected-areas-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: walpole-nornalup-inlets-marine-protected-areas-general-spatial-extent
# Migrating view-of-the-coral-reef-from-the-aims-research-vessel-solander-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: view-of-the-coral-reef-from-the-aims-research-vessel-solander-at-rowley-shoals-marine-park
# Migrating vegetation-monitoring-reports
# ....last updated on
# ....spatial extent
# Updated: vegetation-monitoring-reports
# Migrating vegetation-cover-of-coastal-biological-communities-at-vlamingh-head-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-vlamingh-head-at-ningaloo-mpa
# Migrating vegetation-cover-of-coastal-biological-communities-at-sandy-bay-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-sandy-bay-at-ningaloo-mpa
# Migrating vegetation-cover-of-coastal-biological-communities-at-mangrove-bay-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-mangrove-bay-at-ningaloo-mpa
# Migrating vegetation-cover-of-coastal-biological-communities-at-lefroy-bay-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-lefroy-bay-at-ningaloo-mpa
# Migrating vegetation-cover-of-coastal-biological-communities-at-gnaraloo-bay-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-gnaraloo-bay-at-ningaloo-mpa
# Migrating vegetation-cover-of-coastal-biological-communities-at-combined-sites-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: vegetation-cover-of-coastal-biological-communities-at-combined-sites-at-ningaloo-mpa
# Migrating turtle-tagging-database
# ....last updated on
# ....spatial extent
# Updated: turtle-tagging-database
# Migrating turtle-surface-counts-shark-bay
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: turtle-surface-counts-shark-bay
# Migrating turtle-monitoring-at-embmpa
# ....citation
# ....last updated on
# Updated: turtle-monitoring-at-embmpa
# Migrating turtle-egg-predation-by-foxes-at-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: turtle-egg-predation-by-foxes-at-the-ningaloo-mpa
# Migrating turtle-at-cape-domett
# ....last updated on
# ....spatial extent
# Updated: turtle-at-cape-domett
# Migrating ts-and-rainfall-site-dhi-02
# ....citation
# ....last updated on
# ....spatial extent
# Updated: ts-and-rainfall-site-dhi-02
# Migrating ts-and-rainfall-site-dhi-01
# ....citation
# ....last updated on
# ....spatial extent
# Updated: ts-and-rainfall-site-dhi-01
# Migrating tropical-coral-reef-fish-on-a-shallow-coral-reef-flat-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: tropical-coral-reef-fish-on-a-shallow-coral-reef-flat-at-rowley-shoals-marine-park
# Migrating tributyltin-concentrations-in-sediments-in-the-coral-bay-area-at-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: tributyltin-concentrations-in-sediments-in-the-coral-bay-area-at-the-ningaloo-mpa
# Migrating tributyltin-concentrations-in-sediment-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: tributyltin-concentrations-in-sediment-at-the-shoalwater-islands-mp
# Migrating total-suspended-solids-at-the-montebello-and-barrow-islands-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-suspended-solids-at-the-montebello-and-barrow-islands-mpa
# Migrating total-phosphorus-concentrations-in-the-water-of-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-phosphorus-concentrations-in-the-water-of-walpole-and-nornalup-inlets-mp
# Migrating total-phosphorus-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-phosphorus-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# Migrating total-phosphorus-concentrations-in-the-sediment-at-the-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-phosphorus-concentrations-in-the-sediment-at-the-marmion-mp
# Migrating total-phosphorus-concentrations-at-monkey-mia-at-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-phosphorus-concentrations-at-monkey-mia-at-the-shark-bay-mpa
# Migrating total-petroleum-hydrocarbon-concentrations-in-sediment-at-the-montebello-and-barrow-islands-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-petroleum-hydrocarbon-concentrations-in-sediment-at-the-montebello-and-barrow-islands-mpa
# Migrating total-petroleum-hydrocarbon-concentration-in-coastal-waters-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-petroleum-hydrocarbon-concentration-in-coastal-waters-at-jurien-bay-mp
# Migrating total-nitrogen-inputs-into-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-nitrogen-inputs-into-the-walpole-and-nornalup-inlets-mp
# Migrating total-nitrogen-concentrations-in-the-water-of-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-nitrogen-concentrations-in-the-water-of-walpole-and-nornalup-inlets-mp
# Migrating total-nitrogen-concentrations-at-monkey-mia-at-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-nitrogen-concentrations-at-monkey-mia-at-the-shark-bay-mpa
# Migrating total-kjeldhal-nitrogen-concentrations-in-sediments-at-coral-bay-in-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-kjeldhal-nitrogen-concentrations-in-sediments-at-coral-bay-in-the-ningaloo-mpa
# Migrating total-kjeldahl-nitrogen-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-kjeldahl-nitrogen-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# Migrating total-kjeldahl-nitrogen-concentrations-in-the-sediment-at-the-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: total-kjeldahl-nitrogen-concentrations-in-the-sediment-at-the-marmion-mp
# Migrating the-number-of-whale-sharks-observed-by-marine-tour-operators-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: the-number-of-whale-sharks-observed-by-marine-tour-operators-at-ningaloo-mpa
# Migrating the-number-of-whale-shark-industry-staff-training-courses-undertaken-annually-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: the-number-of-whale-shark-industry-staff-training-courses-undertaken-annually-at-ningaloo-mpa
# Migrating the-number-days-attributed-to-whale-shark-compliance-in-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: the-number-days-attributed-to-whale-shark-compliance-in-the-ningaloo-mpa
# Migrating tern-breeding-abundance-simp
# Unchanged: tern-breeding-abundance-simp
# Migrating test
# ....last updated by -> maintainer
# ....last updated on
# Updated: test
# Migrating temperature-stress-on-little-penguins-on-penguin-island-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: temperature-stress-on-little-penguins-on-penguin-island-at-the-shoalwater-islands-mp
# Migrating swan-river-protected-areas-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: swan-river-protected-areas-general-spatial-extent
# Migrating swan-report
# ....last updated on
# ....spatial extent
# Updated: swan-report
# Migrating swan-mammal-trends
# ....citation
# ....last updated on
# Updated: swan-mammal-trends
# Migrating swan-bird-trends
# ....citation
# ....last updated on
# ....spatial extent
# Updated: swan-bird-trends
# Migrating swan-bird-rates
# ....citation
# ....last updated on
# ....spatial extent
# Updated: swan-bird-rates
# Migrating storms-at-jurien-bay-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: storms-at-jurien-bay-marine-park
# Migrating stuart-field
# ....last updated on
# Updated: stuart-field
# Migrating stock-photo-whale-shark
# Unchanged: stock-photo-whale-shark
# Migrating stock-photo-water-quality-with-chaetodon
# Unchanged: stock-photo-water-quality-with-chaetodon
# Migrating stock-photo-water-quality-at-the-walpole-and-nornalup-inlets-mp
# Unchanged: stock-photo-water-quality-at-the-walpole-and-nornalup-inlets-mp
# Migrating stock-photo-water-quality-at-the-ngari-capes-mp
# Unchanged: stock-photo-water-quality-at-the-ngari-capes-mp
# Migrating stock-photo-water-quality
# Unchanged: stock-photo-water-quality
# Migrating stock-photo-walpole-nornalup-inlet-mp
# Unchanged: stock-photo-walpole-nornalup-inlet-mp
# Migrating stock-photo-turtle-hatchlings
# Unchanged: stock-photo-turtle-hatchlings
# Migrating stock-photo-turtle-being-released-with-transmitter
# Unchanged: stock-photo-turtle-being-released-with-transmitter
# Migrating stock-photo-subtidal-soft-sediment-communities-at-the-ningaloo-mpa
# Unchanged: stock-photo-subtidal-soft-sediment-communities-at-the-ningaloo-mpa
# Migrating stock-photo-swan-estuary
# Unchanged: stock-photo-swan-estuary
# Migrating stock-photo-subtidal-soft-sediment-communities
# Unchanged: stock-photo-subtidal-soft-sediment-communities
# Migrating stock-photo-shoalwater-islands
# Unchanged: stock-photo-shoalwater-islands
# Migrating stock-photo-shark-bay-landscape
# Unchanged: stock-photo-shark-bay-landscape
# Migrating stock-photo-shark
# Unchanged: stock-photo-shark
# Migrating stock-photo-shallow-subtidal-reef-communities-ngari-capes-mp
# Unchanged: stock-photo-shallow-subtidal-reef-communities-ngari-capes-mp
# Migrating stock-photo-sediment-quality-at-the-montebello-and-barrow-islands-mpas
# Unchanged: stock-photo-sediment-quality-at-the-montebello-and-barrow-islands-mpas
# Migrating stock-photo-sediment-quality
# Unchanged: stock-photo-sediment-quality
# Migrating stock-photo-sea-snakes
# Unchanged: stock-photo-sea-snakes
# Migrating stock-photo-seascapes-in-the-northern-marine-parks
# Unchanged: stock-photo-seascapes-in-the-northern-marine-parks
# Migrating stock-photo-seascapes-in-the-metropolitan-region
# Unchanged: stock-photo-seascapes-in-the-metropolitan-region
# Migrating stock-photo-seascapes-in-jurien-bay-ningaloo-and-shark-bay-mpas
# Unchanged: stock-photo-seascapes-in-jurien-bay-ningaloo-and-shark-bay-mpas
# Migrating stock-photo-seascapes-at-the-ngari-capes-mp
# Unchanged: stock-photo-seascapes-at-the-ngari-capes-mp
# Migrating stock-photo-seascapes-and-wilderness-at-the-rowley-shoals-mp
# Unchanged: stock-photo-seascapes-and-wilderness-at-the-rowley-shoals-mp
# Migrating stock-photo-sea-lions-in-jurien-bay
# Unchanged: stock-photo-sea-lions-in-jurien-bay
# Migrating stock-photo-seagrass-communities
# Unchanged: stock-photo-seagrass-communities
# Migrating stock-photo-seagrass-and-macroalgae-communities-ngari-capes-mp
# Unchanged: stock-photo-seagrass-and-macroalgae-communities-ngari-capes-mp
# Migrating stock-photo-seabirds-in-the-mid-west-and-metropolitan-regions
# Unchanged: stock-photo-seabirds-in-the-mid-west-and-metropolitan-regions
# Migrating stock-photo-seabirds-in-the-kimberley-and-pilbara-mps
# Unchanged: stock-photo-seabirds-in-the-kimberley-and-pilbara-mps
# Migrating stock-photo-seabirds-at-the-walpole-and-nornalup-inlets-mp
# Unchanged: stock-photo-seabirds-at-the-walpole-and-nornalup-inlets-mp
# Migrating stock-photo-seabirds-at-the-ngari-capes-mp
# Unchanged: stock-photo-seabirds-at-the-ngari-capes-mp
# Migrating stock-photo-seabirds-at-the-jurien-bay-mp
# Unchanged: stock-photo-seabirds-at-the-jurien-bay-mp
# Migrating stock-photo-seabed-geomorphology
# Unchanged: stock-photo-seabed-geomorphology
# Migrating stock-photo-port-jackson
# Unchanged: stock-photo-port-jackson
# Migrating stock-photo-ngari-capes
# Unchanged: stock-photo-ngari-capes
# Migrating stock-photo-microbial-communities-at-shark-bay-mpas
# Unchanged: stock-photo-microbial-communities-at-shark-bay-mpas
# Migrating stock-photo-marmion-coastline
# Unchanged: stock-photo-marmion-coastline
# Migrating stock-photo-marine-turtle-in-the-kimberley-marine-parks
# Unchanged: stock-photo-marine-turtle-in-the-kimberley-marine-parks
# Migrating stock-photo-marine-parks-boat
# Unchanged: stock-photo-marine-parks-boat
# Migrating stock-photo-manta-ray
# Unchanged: stock-photo-manta-ray
# Migrating stock-photo-mangrove-communities-at-shark-bay-mpas
# Unchanged: stock-photo-mangrove-communities-at-shark-bay-mpas
# Migrating stock-photo-mangrove-communities-at-lalang-garram-camden-sound-mp
# Unchanged: stock-photo-mangrove-communities-at-lalang-garram-camden-sound-mp
# Migrating stock-photo-mangrove-communities
# Unchanged: stock-photo-mangrove-communities
# Migrating stock-photo-little-penguins-at-the-shoalwater-islands-mp
# Unchanged: stock-photo-little-penguins-at-the-shoalwater-islands-mp
# Migrating stock-photo-invertebrate-communities-ngari-capes-mp
# Unchanged: stock-photo-invertebrate-communities-ngari-capes-mp
# Migrating stock-photo-invertebrate-communities
# Unchanged: stock-photo-invertebrate-communities
# Migrating stock-photo-intertidal-sand-and-mudflat-communities
# Unchanged: stock-photo-intertidal-sand-and-mudflat-communities
# Migrating stock-photo-intertidal-rock-reef-communities-ngari-capes-mp
# Unchanged: stock-photo-intertidal-rock-reef-communities-ngari-capes-mp
# Migrating stock-photo-intertidal-reef-communities-tropical
# Unchanged: stock-photo-intertidal-reef-communities-tropical
# Migrating stock-photo-intertidal-reef-communities-metro
# Unchanged: stock-photo-intertidal-reef-communities-metro
# Migrating stock-photo-finfish-at-the-shark-bay-mpas
# Unchanged: stock-photo-finfish-at-the-shark-bay-mpas
# Migrating stock-photo-finfish-at-the-ngari-capes-mp
# Unchanged: stock-photo-finfish-at-the-ngari-capes-mp
# Migrating stock-photo-filter-feeder-communities-sponges
# Unchanged: stock-photo-filter-feeder-communities-sponges
# Migrating stock-photo-dugong
# Unchanged: stock-photo-dugong
# Migrating stock-photo-dolphins-at-the-lalang-garram-camden-sound-mp
# Unchanged: stock-photo-dolphins-at-the-lalang-garram-camden-sound-mp
# Migrating stock-photo-dolphins-at-monkey-mia-in-the-shark-bay-mpas
# Unchanged: stock-photo-dolphins-at-monkey-mia-in-the-shark-bay-mpas
# Migrating stock-photo-deep-reef-communities-ngari-capes
# Unchanged: stock-photo-deep-reef-communities-ngari-capes
# Migrating stock-photo-crocodiles
# Unchanged: stock-photo-crocodiles
# Migrating stock-photo-coral-reef-communities
# Unchanged: stock-photo-coral-reef-communities
# Migrating stock-photo-coral-at-eagle-bay
# Unchanged: stock-photo-coral-at-eagle-bay
# Migrating stock-photo-coral-and-fish
# Unchanged: stock-photo-coral-and-fish
# Migrating stock-photo-common-indicators
# Unchanged: stock-photo-common-indicators
# Migrating stock-photo-coastal-biological-communities-in-walpole-and-nornalup-inlets-mp
# Unchanged: stock-photo-coastal-biological-communities-in-walpole-and-nornalup-inlets-mp
# Migrating stock-photo-coastal-biological-communities
# Unchanged: stock-photo-coastal-biological-communities
# Migrating stock-photo-cetaceans
# Unchanged: stock-photo-cetaceans
# Migrating stock-photo-blue-spotted-ray
# Unchanged: stock-photo-blue-spotted-ray
# Migrating stock-photo-australian-sea-lions
# Unchanged: stock-photo-australian-sea-lions
# Migrating stock-photo-aesthetic-values-in-the-walpole-and-nornalup-inlets-mp
# Unchanged: stock-photo-aesthetic-values-in-the-walpole-and-nornalup-inlets-mp
# Migrating species-diversity-of-primary-producers-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: species-diversity-of-primary-producers-at-the-walpole-and-nornalup-inlets-mp
# Migrating starfish-at-metro-marine-parks
# ....last updated on
# ....spatial extent
# Updated: starfish-at-metro-marine-parks
# Migrating species-diversity-of-macroalgae-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: species-diversity-of-macroalgae-at-jurien-bay-mp
# Migrating species-abundance-of-finfish-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: species-abundance-of-finfish-at-ningaloo-mpa
# Migrating spatial-extent-of-microbial-communities-in-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-microbial-communities-in-the-shark-bay-mpa
# Migrating spatial-extent-of-mangrove-communities-at-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-mangrove-communities-at-the-shark-bay-mpa
# Migrating spatial-extent-of-broad-scale-habitats-within-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-walpole-and-nornalup-inlets-mp
# Migrating spatial-extent-of-broad-scale-habitats-within-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-shoalwater-islands-mp
# Migrating spatial-extent-of-broad-scale-habitats-within-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-shark-bay-mpa
# Migrating spatial-extent-of-broad-scale-habitats-within-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-ningaloo-mpa
# Migrating spatial-extent-of-broad-scale-habitats-within-the-ngari-capes-mp
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-ngari-capes-mp
# Migrating spatial-extent-of-broad-scale-habitats-within-the-montebello-and-barrow-islands
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-montebello-and-barrow-islands
# Migrating spatial-extent-of-broad-scale-habitats-within-the-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-marmion-mp
# Migrating spatial-extent-of-broad-scale-habitats-within-the-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-the-jurien-bay-mp
# Migrating spatial-extent-of-broad-scale-habitats-within-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: spatial-extent-of-broad-scale-habitats-within-rowley-shoals-marine-park
# Migrating soluble-reactive-phosphorus-concentration-in-the-water-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: soluble-reactive-phosphorus-concentration-in-the-water-at-the-walpole-and-nornalup-inlets-mp
# Migrating shorebirds-abundance-at-80-mile-beach-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: shorebirds-abundance-at-80-mile-beach-marine-park
# Migrating shoot-density-ngari-capes-product-page
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: shoot-density-ngari-capes-product-page
# Migrating shoalwater-mpa-geomorphology-tern-island
# ....citation
# ....last updated on
# ....spatial extent
# Updated: shoalwater-mpa-geomorphology-tern-island
# Migrating shoalwater-islands-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: shoalwater-islands-general-spatial-extent
# Migrating shell-size-change-of-the-targeted-invertebrate-haliotis-roei-at-the-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: shell-size-change-of-the-targeted-invertebrate-haliotis-roei-at-the-marmion-mp
# Migrating shark-bay-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: shark-bay-general-spatial-extent
# Migrating shark-bay-fish-length-and-abundance-from-eventmeasure-diver-operated-video-in-june-2011
# ....last updated on
# ....spatial extent
# Updated: shark-bay-fish-length-and-abundance-from-eventmeasure-diver-operated-video-in-june-2011
# Migrating shark-bay-benthic-data-from-ecopaas-in-june-2010
# ....last updated on
# ....spatial extent
# Updated: shark-bay-benthic-data-from-ecopaas-in-june-2010
# Migrating sewerage-connections-walpole-nornalup-inlets-marine-park
# ....citation
# ....last updated on
# Updated: sewerage-connections-walpole-nornalup-inlets-marine-park
# Migrating sediment-particle-size-at-the-montebello-and-barrow-islands
# ....citation
# ....last updated on
# ....spatial extent
# Updated: sediment-particle-size-at-the-montebello-and-barrow-islands
# Migrating sediment-deposition-at-the-montebello-and-barrow-islands
# ....citation
# ....last updated on
# ....spatial extent
# Updated: sediment-deposition-at-the-montebello-and-barrow-islands
# Migrating sea-temperatures-likely-readable-real-time-with-new-model-media-release
# ....last updated on
# ....spatial extent
# Updated: sea-temperatures-likely-readable-real-time-with-new-model-media-release
# Migrating sea-urchin-at-ngari-capes-marine-park
# ....last updated on
# ....spatial extent
# Updated: sea-urchin-at-ngari-capes-marine-park
# Migrating sea-surface-temperature-and-in-situ-water-temperature-across-western-australian-mpas
# ....last updated on
# ....spatial extent
# Updated: sea-surface-temperature-and-in-situ-water-temperature-across-western-australian-mpas
# Migrating seasnakes-shark-bay
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: seasnakes-shark-bay
# Migrating sea-lions-in-the-south-west-of-western-australia
# ....last updated on
# ....spatial extent
# Updated: sea-lions-in-the-south-west-of-western-australia
# Migrating seagrass-ningaloo
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: seagrass-ningaloo
# Migrating seagrass-in-situ-surveys-in-western-australia-shoot-density-at-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-shoot-density-at-shoalwater-islands-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-shoot-density-at-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-shoot-density-at-shark-bay-mpa
# Migrating seagrass-in-situ-surveys-in-western-australia-shoot-density-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-shoot-density-at-marmion-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-shoot-density-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-shoot-density-at-jurien-bay-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-percent-cover-at-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-percent-cover-at-shoalwater-islands-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-canopy-height-at-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-canopy-height-at-shoalwater-islands-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-canopy-height-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-canopy-height-at-marmion-mp
# Migrating seagrass-in-situ-surveys-in-western-australia-canopy-height-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-canopy-height-at-jurien-bay-mp
# Migrating seagrass-in-situ-surveys-in-western-australia
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia
# Migrating seagrass-height-and-density-at-cockburn-sound
# ....last updated on
# ....spatial extent
# Updated: seagrass-height-and-density-at-cockburn-sound
# Migrating seabirds-and-shorebirds-shoalwater-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seabirds-and-shorebirds-shoalwater-marine-park
# Migrating seabirds-and-shorebirds-pressures-shoalwater-marine-park
# Unchanged: seabirds-and-shorebirds-pressures-shoalwater-marine-park
# Migrating scalefish-catch-per-unit-effort-in-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: scalefish-catch-per-unit-effort-in-the-shark-bay-mpa
# Migrating sandy-shoreline-at-eighty-mile-beach-mp
# Unchanged: sandy-shoreline-at-eighty-mile-beach-mp
# Migrating saltwater-crocodile-crocodilus-porosus-populations-in-the-west-kimberley
# ....citation
# ....last updated on
# ....spatial extent
# Updated: saltwater-crocodile-crocodilus-porosus-populations-in-the-west-kimberley
# Migrating sailfin-snapper-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: sailfin-snapper-at-rowley-shoals-marine-park
# Migrating rowley-shoals-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: rowley-shoals-general-spatial-extent
# Migrating rttb-annual-count-1967-2914-jpg
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# ....spatial extent
# Updated: rttb-annual-count-1967-2914-jpg
# Migrating rowley-shoals-fish-length-and-abundance-from-eventmeasure-diver-operated-video-in-september-2011
# ....last updated on
# ....spatial extent
# Updated: rowley-shoals-fish-length-and-abundance-from-eventmeasure-diver-operated-video-in-september-2011
# Migrating rosie-the-loggerhead-turtle-release-in-exmouth-on-17-december-2013
# ....last updated on
# ....spatial extent
# Updated: rosie-the-loggerhead-turtle-release-in-exmouth-on-17-december-2013
# Migrating rowley-shoals-benthic-data-from-ecopaas-in-december-2012
# ....last updated on
# ....spatial extent
# Updated: rowley-shoals-benthic-data-from-ecopaas-in-december-2012
# Migrating river-discharge-into-the-swan-canning-estuary-from-the-avon-and-canning-rivers-catchment
# ....citation
# ....last updated on
# ....spatial extent
# Updated: river-discharge-into-the-swan-canning-estuary-from-the-avon-and-canning-rivers-catchment
# Migrating river-discharge-from-the-major-drains-creeks-and-rivers-relevant-to-the-ngari-capes-marine-park
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: river-discharge-from-the-major-drains-creeks-and-rivers-relevant-to-the-ngari-capes-marine-park
# Migrating river-discharge-from-the-hill-river-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: river-discharge-from-the-hill-river-at-jurien-bay-mp
# Migrating river-discharge-from-the-gascoyne-and-wooramel-rivers-in-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: river-discharge-from-the-gascoyne-and-wooramel-rivers-in-the-shark-bay-mpa
# Migrating relative-prevalence-of-coral-disease-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: relative-prevalence-of-coral-disease-at-ningaloo-mpa
# Migrating relative-abundance-of-finfish-in-the-ngari-capes-mp
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# ....spatial extent
# Updated: relative-abundance-of-finfish-in-the-ngari-capes-mp
# Migrating reef-lagoons-at-rowley-shoals-mp
# Unchanged: reef-lagoons-at-rowley-shoals-mp
# Migrating reef-lagoons-at-montebello-islands-mp
# Unchanged: reef-lagoons-at-montebello-islands-mp
# Migrating red-tailed-tropic-bird-on-a-beach-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: red-tailed-tropic-bird-on-a-beach-at-the-rowley-shoals-marine-park
# Migrating recruitment-of-seabirds-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recruitment-of-seabirds-at-the-rowley-shoals-marine-park
# Migrating recruitment-of-finfish-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recruitment-of-finfish-at-ningaloo-mpa
# Migrating recruitment-index-for-puerulus-of-panulirus-cygnus-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recruitment-index-for-puerulus-of-panulirus-cygnus-at-ningaloo-mpa
# Migrating recreational-western-rock-lobster-catch
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: recreational-western-rock-lobster-catch
# Migrating recreational-fishing-from-boat-licences-in-the-south-west-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-south-west-region
# Migrating recreational-fishing-from-boat-licences-in-the-south-coast-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-south-coast-region
# Migrating recreational-fishing-from-boat-licences-in-the-shark-bay-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-shark-bay-region
# Migrating recreational-fishing-from-boat-licences-in-the-pilbara-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-pilbara-region
# Migrating recreational-fishing-from-boat-licences-in-the-metropolitan-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-metropolitan-region
# Migrating recreational-fishing-from-boat-licences-in-the-kimberley-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-kimberley-region
# Migrating recreational-fishing-from-boat-licences-in-the-jurien-bay-region
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-in-the-jurien-bay-region
# Migrating recreational-fishing-from-boat-licences-dataset
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-from-boat-licences-dataset
# Migrating recreational-fishing-effort-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recreational-fishing-effort-at-the-walpole-and-nornalup-inlets-mp
# Migrating recorded-number-of-oil-spills-at-barrow-island-port
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recorded-number-of-oil-spills-at-barrow-island-port
# Migrating recorded-mortalities-of-little-penguins-on-penguin-island-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: recorded-mortalities-of-little-penguins-on-penguin-island-at-the-shoalwater-islands-mp
# Migrating rainfall-relevant-to-the-perth-metropolitan-marine-protected-areas
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: rainfall-relevant-to-the-perth-metropolitan-marine-protected-areas
# Migrating rainfall-relevant-to-eighty-mile-beach-marine-park
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: rainfall-relevant-to-eighty-mile-beach-marine-park
# Migrating rainfall-at-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: rainfall-at-the-shark-bay-mpa
# Migrating rainfall-at-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: rainfall-at-the-ningaloo-mpa
# Migrating rainfall-at-the-montebello-and-barrow-islands
# ....citation
# ....last updated on
# ....spatial extent
# Updated: rainfall-at-the-montebello-and-barrow-islands
# Migrating rainfall-at-cygnet-bay
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# Updated: rainfall-at-cygnet-bay
# Migrating quenda-monitoring-in-julimar-sf
# Unchanged: quenda-monitoring-in-julimar-sf
# Migrating quenda-monitoring-at-ellenbrook-nr
# Unchanged: quenda-monitoring-at-ellenbrook-nr
# Migrating predator-pressures-on-turtle-nests-at-embmp
# ....citation
# ....last updated on
# Updated: predator-pressures-on-turtle-nests-at-embmp
# Migrating potato-cod-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: potato-cod-at-rowley-shoals-marine-park
# Migrating polycyclic-aromatic-hydrocarbon-concentrations-in-the-water-of-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: polycyclic-aromatic-hydrocarbon-concentrations-in-the-water-of-jurien-bay-mp
# Migrating polycyclic-aromatic-hydrocarbon-concentrations-in-the-sediments-of-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: polycyclic-aromatic-hydrocarbon-concentrations-in-the-sediments-of-the-ningaloo-mpa
# Migrating polycyclic-aromatic-hydrocarbon-concentrations-in-the-sediments-of-the-montebello-and-barrow-islands
# ....citation
# ....last updated on
# ....spatial extent
# Updated: polycyclic-aromatic-hydrocarbon-concentrations-in-the-sediments-of-the-montebello-and-barrow-islands
# Migrating pilbara-islands-wgs84-shapefile
# ....last updated on
# Updated: pilbara-islands-wgs84-shapefile
# Migrating phosphorus-concentrations-in-the-water-at-the-swan-estuary-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: phosphorus-concentrations-in-the-water-at-the-swan-estuary-mp
# Migrating pesticide-concentrations-in-the-water-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: pesticide-concentrations-in-the-water-at-jurien-bay-mp
# Migrating pesticide-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: pesticide-concentrations-in-the-sediment-at-the-walpole-and-nornalup-inlets-mp
# Migrating pesticide-concentrations-in-the-sediment-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: pesticide-concentrations-in-the-sediment-at-marmion-mp
# Migrating person-days-at-the-walpole-and-nornalup-inlets-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-walpole-and-nornalup-inlets-mp-water-quality
# Migrating person-days-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-walpole-and-nornalup-inlets-mp
# Migrating person-days-at-the-swan-estuary-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp-water-quality
# Migrating person-days-at-the-swan-estuary-mp-sediment-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp-sediment-quality
# Migrating person-days-at-the-swan-estuary-mp-seagrass-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp-seagrass-communities
# Migrating person-days-at-the-swan-estuary-mp-seabirds
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp-seabirds
# Migrating person-days-at-the-swan-estuary-mp-invertebrate-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp-invertebrate-communities
# Migrating person-days-at-the-swan-estuary-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-swan-estuary-mp
# Migrating person-days-at-the-shoalwater-islands-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-water-quality
# Migrating person-days-at-the-shoalwater-islands-mp-subtidal-soft-bottom-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-subtidal-soft-bottom-communities
# Migrating person-days-at-the-shoalwater-islands-mp-sediment-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-sediment-quality
# Migrating person-days-at-the-shoalwater-islands-mp-seagrass-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-seagrass-communities
# Migrating person-days-at-the-shoalwater-islands-mp-macroalgae-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-macroalgae-communities
# Migrating person-days-at-the-shoalwater-islands-mp-little-penguins
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-little-penguins
# Migrating person-days-at-the-shoalwater-islands-mp-invertebrate-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-invertebrate-communities
# Migrating person-days-at-the-shoalwater-islands-mp-geomorphology
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-geomorphology
# Migrating person-days-at-the-shoalwater-islands-mp-finfish-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-finfish-communities
# Migrating person-days-at-the-shoalwater-islands-mp-cetaceans
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-cetaceans
# Migrating person-days-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp
# Migrating person-days-at-the-shark-bay-mp-wilderness
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-wilderness
# Migrating person-days-at-the-shark-bay-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-water-quality
# Migrating person-days-at-the-shark-bay-mp-sediment-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-sediment-quality
# Migrating person-days-at-the-shark-bay-mp-sea-snakes
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-sea-snakes
# Migrating person-days-at-the-shark-bay-mp-seascapes
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-seascapes
# Migrating person-days-at-the-shark-bay-mp-seagrass-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-seagrass-communities
# Migrating person-days-at-the-shark-bay-mp-seabirds
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-seabirds
# Migrating person-days-at-the-shark-bay-mp-microbial-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-microbial-communities
# Migrating person-days-at-the-shark-bay-mp-marine-turtles
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-marine-turtles
# Migrating person-days-at-the-shark-bay-mp-mangrove-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-mangrove-communities
# Migrating person-days-at-the-shark-bay-mp-invertebrate-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-invertebrate-communities
# Migrating person-days-at-the-shark-bay-mp-geomorphology
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-geomorphology
# Migrating person-days-at-the-shark-bay-mp-finfish-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-finfish-communities
# Migrating person-days-at-the-shark-bay-mp-dugongs
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-dugongs
# Migrating person-days-at-the-shark-bay-mp-coral-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-coral-communities
# Migrating person-days-at-the-shark-bay-mp-cetaceans
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp-cetaceans
# Migrating person-days-at-the-shark-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shark-bay-mp
# Migrating person-days-at-the-rowley-shoals-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-water-quality
# Migrating person-days-at-the-rowley-shoals-mp-turtles
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-turtles
# Migrating person-days-at-the-rowley-shoals-mp-seascapes
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-seascapes
# Migrating person-days-at-the-rowley-shoals-mp-invertebrates
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-invertebrates
# Migrating person-days-at-the-rowley-shoals-mp-seabirds
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-seabirds
# Migrating person-days-at-the-rowley-shoals-mp-finfish
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-finfish
# Migrating person-days-at-the-rowley-shoals-mp-coral
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-coral
# Migrating person-days-at-the-rowley-shoals-mp-cetaceans
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp-cetaceans
# Migrating person-days-at-the-rowley-shoals-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-mp
# Migrating person-days-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-rowley-shoals-marine-park
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-water-quality
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-turtles
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-turtles
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-sediment-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-sediment-quality
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-seabirds
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-seabirds
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-primary-producers
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-primary-producers
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-mooring-maintenance
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-mooring-maintenance
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-marine-mammals
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-marine-mammals
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-mangrove-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-mangrove-communities
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-invertebrate-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-invertebrate-communities
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-hydrocarbons
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-hydrocarbons
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-geomorphology
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-geomorphology
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-finfish-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-finfish-communities
# Migrating person-days-at-the-montebello-and-barrow-islands-mp-coral-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp-coral-communities
# Migrating person-days-at-the-montebello-and-barrow-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-montebello-and-barrow-islands-mp
# Migrating person-days-at-the-marmion-mp-water-quality
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-marmion-mp-water-quality
# ...
# ....spatial extent
# Updated: annual-recreational-catch-of-the-targeted-invertebrate-panulirus-cygnus
# Migrating annual-commercial-take-of-targeted-invertebrates-in-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: annual-commercial-take-of-targeted-invertebrates-in-the-shark-bay-mpa
# Migrating anemone-giant-clam-and-fish-at-rowley-shoals-marine-park
# ....last updated on
# ....spatial extent
# Updated: anemone-giant-clam-and-fish-at-rowley-shoals-marine-park
# Migrating amount-of-provisioned-fish-for-dolphins-at-the-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: amount-of-provisioned-fish-for-dolphins-at-the-shark-bay-mpa
# Migrating a-general-description-of-the-subtidal-habitats-of-the-dampier-archipelago-western-australia
# ....last updated on
# ....spatial extent
# Updated: a-general-description-of-the-subtidal-habitats-of-the-dampier-archipelago-western-australia
# Migrating acanthaster-planci-at-montebello-islands
# ....last updated on
# ....spatial extent
# Updated: acanthaster-planci-at-montebello-islands
# Migrating abundance-of-waterbirds-at-the-swan-estuary-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-waterbirds-at-the-swan-estuary-mp
# Migrating abundance-of-the-targeted-invertebrate-panulirus-larvae-at-the-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-panulirus-larvae-at-the-jurien-bay-mp
# Migrating abundance-of-the-targeted-invertebrate-panulirus-cygnus-larvae
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-panulirus-cygnus-larvae
# Migrating abundance-of-the-targeted-invertebrate-panulirus-at-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-panulirus-at-the-ningaloo-mpa
# Migrating abundance-of-the-targeted-invertebrate-panulirus-at-the-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-panulirus-at-the-jurien-bay-mp
# Migrating abundance-of-the-targeted-invertebrate-haliotis-spp-at-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-haliotis-spp-at-shoalwater-islands-mp
# Migrating abundance-of-the-targeted-invertebrate-haliotis-spp-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-haliotis-spp-at-marmion-mp
# Migrating abundance-of-the-targeted-invertebrate-haliotis-spp-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-targeted-invertebrate-haliotis-spp-at-jurien-bay-mp
# Migrating abundance-of-the-seabird-pied-cormorant-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-the-seabird-pied-cormorant-at-marmion-mp
# Migrating abundance-of-target-finfish-species-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-the-walpole-and-nornalup-inlets-mp
# Migrating abundance-of-target-finfish-species-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-the-rowley-shoals-marine-park
# Migrating abundance-of-target-finfish-species-at-the-montebello-and-barrow-islands-marine-protected-areas
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-the-montebello-and-barrow-islands-marine-protected-areas
# Migrating abundance-of-target-finfish-species-at-the-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-the-jurien-bay-mp
# Migrating abundance-of-target-finfish-species-at-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-shark-bay-mpa
# Migrating abundance-of-target-finfish-species-at-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-target-finfish-species-at-marmion-mp
# Migrating abundance-of-targeted-finfish-species-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-targeted-finfish-species-at-the-shoalwater-islands-mp
# Migrating abundance-of-sharks-and-rays-at-skeleton-bay-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-sharks-and-rays-at-skeleton-bay-at-ningaloo-mpa
# Migrating abundance-of-seabirds-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-seabirds-at-the-rowley-shoals-marine-park
# Migrating abundance-of-non-targeted-invertebrate-species-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-non-targeted-invertebrate-species-at-jurien-bay-mp
# Migrating abundance-of-manta-rays-at-the-ningaloo-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-manta-rays-at-the-ningaloo-mp
# Migrating abundance-of-invertebrates-in-the-ngari-capes-marine-park
# ....citation
# ....last updated by -> maintainer
# ....last updated on
# ....spatial extent
# Updated: abundance-of-invertebrates-in-the-ngari-capes-marine-park
# Migrating abundance-of-invertebrates-at-the-walpole-and-nornalup-inlets-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-invertebrates-at-the-walpole-and-nornalup-inlets-mp
# Migrating abundance-of-intertidal-invertebrates-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-intertidal-invertebrates-at-the-shoalwater-islands-mp
# Migrating abundance-of-intertidal-invertebrates-at-the-marmion-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-intertidal-invertebrates-at-the-marmion-mp
# Migrating abundance-of-indicator-sharks-and-rays-at-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-indicator-sharks-and-rays-at-ningaloo-mpa
# Migrating abundance-of-birds-at-walpole-and-nornalup-inlets-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-birds-at-walpole-and-nornalup-inlets-marine-park
# Migrating abundance-of-australian-sea-lions-on-seal-island-in-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-australian-sea-lions-on-seal-island-in-the-shoalwater-islands-mp
# Migrating abundance-of-australian-sea-lions-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-australian-sea-lions-at-jurien-bay-mp
# Migrating abundance-of-australian-sea-lion-pups-at-jurien-bay-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-of-australian-sea-lion-pups-at-jurien-bay-mp
# Migrating abundance-and-community-composition-of-marine-invertebrates-at-the-rowley-shoals-marine-park
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-and-community-composition-of-marine-invertebrates-at-the-rowley-shoals-marine-park
# Migrating abundance-and-community-composition-of-marine-invertebrates-at-the-ningaloo-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-and-community-composition-of-marine-invertebrates-at-the-ningaloo-mpa
# Migrating abundance-and-community-composition-of-australian-sea-lions-at-the-metro-marine-parks
# ....citation
# ....last updated on
# ....spatial extent
# Updated: abundance-and-community-composition-of-australian-sea-lions-at-the-metro-marine-parks
# Migrating 80-mile-beach-general-spatial-extent
# ....last updated on
# ....spatial extent
# Updated: 80-mile-beach-general-spatial-extent
# Migrating 2012-aerial-photography-of-the-ngari-capes-marine-protected-area
# ....last updated on
# ....spatial extent
# Updated: 2012-aerial-photography-of-the-ngari-capes-marine-protected-area
# Migrating biodiversity-values-on-selected-kimberley-islands
# ....last updated on
# ....spatial extent
# Updated: biodiversity-values-on-selected-kimberley-islands
# Migrating cetacean-mortality-ningaloo
# ....citation
# ....last updated on
# ....spatial extent
# Updated: cetacean-mortality-ningaloo
# Migrating yanchep-camera-trapping
# Unchanged: yanchep-camera-trapping
# Migrating seagrass-in-situ-surveys-in-western-australia-canopy-height-at-shark-bay-mpa
# ....citation
# ....last updated on
# ....spatial extent
# Updated: seagrass-in-situ-surveys-in-western-australia-canopy-height-at-shark-bay-mpa
# Migrating person-days-at-the-shoalwater-islands-mp-australian-sea-lions
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-australian-sea-lions
# Migrating other-baleen-whales-in-wa
# ....last updated by -> maintainer
# ....last updated on
# Updated: other-baleen-whales-in-wa
# Migrating canopy-density-of-mangroves-at-the-shark-bay-mpa-fowlers-bay
# ....citation
# ....last updated on
# ....spatial extent
# Updated: canopy-density-of-mangroves-at-the-shark-bay-mpa-fowlers-bay
# Migrating loss-and-gain-in-canopy-density-of-mangroves-at-the-montebello-and-barrow-islands-mp-combined-sites
# ....citation
# ....last updated on
# ....spatial extent
# Updated: loss-and-gain-in-canopy-density-of-mangroves-at-the-montebello-and-barrow-islands-mp-combined-sites
# Migrating operational-funds-for-the-shark-bay-mp-cetaceans
# ....citation
# ....last updated on
# ....spatial extent
# Updated: operational-funds-for-the-shark-bay-mp-cetaceans
# Migrating coral-cover-in-the-dampier-archipelago-in-2008-for-the-pluto-project-crc158
# ....last updated on
# ....spatial extent
# Updated: coral-cover-in-the-dampier-archipelago-in-2008-for-the-pluto-project-crc158
# Migrating number-of-visitors-to-carnac-islands-at-the-shoalwater-islands-mp
# ....citation
# ....last updated on
# ....spatial extent
# Updated: number-of-visitors-to-carnac-islands-at-the-shoalwater-islands-mp
# Migrating humpback-whale-population-in-western-australia
# ....citation
# ....last updated on
# ....spatial extent
# Updated: humpback-whale-population-in-western-australia
# Migrating person-days-at-the-shoalwater-islands-mp-intertidal-reef-communities
# ....citation
# ....last updated on
# ....spatial extent
# Updated: person-days-at-the-shoalwater-islands-mp-intertidal-reef-communities
# Migrating control-chart-resources
# Unchanged: control-chart-resources
# [True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False]

# %% [markdown]
# ## Apply functions, update CKAN data

# %%
s = [[x["title"],
      ", ".join([tag["name"] for tag in x["tags"]]).replace("_"," ").title(),
      x["maintainer"],
      x["organization"]["title"],
      "{0}dataset/{1}".format(url, x["id"])
      ] for x in ds]

import csv
with open('datasets.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerows(s)

# %%
# Rename extra fields of datasets
#datasets = get_all_dataset_dicts()
#[rename_extra_field(d, "Format cleared for release by:", "Format cleared for release by", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "Format cleared for release on:", "Format cleared for release on", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "Content cleared for release by:", "Content cleared for release by", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "content_cleared_for_release_on", "Content cleared for release on", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "content_cleared_for_release_by", "Content cleared for release by", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "format_cleared_for_release_on", "Format cleared for release on", api_key=api_key) for d in datasets]
#[rename_extra_field(d, "format_cleared_for_release_by", "Format cleared for release by", api_key=api_key) for d in datasets]

# Add extra fields "Last updated on/by" to all datasets
#dataset_list_of_dicts = get_all_dataset_dicts(ckan_instance=ckan_instance, action_api=action_api)
#[add_last_updated_fields(d, api_key=api_key) for d in datasets]
    
# Add an existing tag to datasets of a group    
#datasets_mpa = get_dataset_dicts_for_group-("mpa-reporting")
#tag = get_tag_dict_from_tag_name("mpa_incomplete")
#[add_tag_to_dataset(d, tag, api_key=api_key) for d in datasets_mpa]
#[rename_extra_field(d, "Last updated on", "lats_updated_on", api_key=api_key) for d in ds]
#regional_profile_datasets = get_dataset_dicts_for_tag("regional_profile")
#avw01_datasets = get_dataset_dicts_for_tag("ibra_{0}".format("avw01"))
t = '<a class="btn btn-primary btn-xs" href="{0}">{1}</a>'
''.join([t.format(r["url"], r["name"]) 
         for r in a["resources"] 
         for a in 
         get_dataset_dicts_for_tag("ibra_{0}".format("avw01"))])
# Out:
# '<a class="btn btn-primary btn-xs" href="http://internal-data.dpaw.wa.gov.au/dataset/824e1cc2-a76f-457b-81dc-2c60e50c9a52/resource/b435f1b2-4d4b-494c-bc4d-badcac8ae849/download/Sub-Region-Profile-Reporting-Tables-AVW01.pdf">Regional Profile IBRA Subregion AVW01</a>'

# %%
# Add a new tag to datasets with an old tag - both tags must exist
ds = get_dataset_dicts_for_tag("author_rachael_middlebrook")
new_tag = get_tag_dict_from_tag_name("author_rachael_marshall")
[add_tag_to_dataset(d, new_tag, url, key) for d in ds]
# Out:
# Tag found, skipping number-of-storms-at-montebello-and-barrow-islands-mpa
# Tag found, skipping department-of-fisheries-patrols-and-other-activities-at-the-montebello-and-barrow-islands
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp-turtles
# Tag found, skipping number-of-tourists-visiting-montebello-and-barrow-islands-with-commercial-tour-operators
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp-mangrove-communities
# Tag found, skipping number-of-vessels-utilising-the-barrow-island-port
# Tag found, skipping number-of-patrols-undertaken-at-the-montebello-and-barrow-islands
# Tag found, skipping district-staff-days-attributed-to-oil-spill-response-training-for-the-montebello-and-barrow-islands
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp-water-quality
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp-finfish-communities
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-coral-communities
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-sediment-quality
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-mangrove-communities
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-marine-mammals
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-primary-producers
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-invertebrate-communities
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-water-quality
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-finfish-communities
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-hydrocarbons
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-turtles
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-geomorphology
# Tag found, skipping person-days-at-the-montebello-and-barrow-islands-mp-seabirds
# Tag found, skipping operational-funds-for-the-montebello-and-barrow-islands-mp-coral-reef-communities
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]
